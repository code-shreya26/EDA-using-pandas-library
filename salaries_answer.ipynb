# %%
pwd
# Out:
# 'C:\\Users\\ak'

# %%
# Importing panda library
import pandas as pd

# %%
# Getting required data and store it in sal variable
sal=pd.read_csv('Salaries.csv',dtype=str)

# %%
pd.DataFrame(sal)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
# Getting data for above five rows
sal.head(5)
# Out:
#   Id       EmployeeName                                        JobTitle  \
# 0  1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1  2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2  3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4  5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43        567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28        538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91        335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61        332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19        326373.19
#
#    Year Notes         Agency Status
# 0  2011   NaN  San Francisco    NaN
# ...

# %%
# Getting information regarding different features
sal.info() #dtype=object means str
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  object
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  object
#  8   TotalPayBenefits  148654 non-null  object
#  9   Year              148654 non-null  object
#  10  Notes             0 non-null       object
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: object(13)
# memory usage: 14.7+ MB

# %%
#calculating average basepay
sal['BasePay'].isna().sum()
# Out:
# 0

# %%
lambda x:x.replace('Not provided',0 )
# Out:
# <function __main__.<lambda>(x)>

# %%
sal['BasePay']=sal['BasePay'].apply(lambda x:str(x).replace("Not Provided","0" ))

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
sal_basepay=sal['BasePay'].astype('float')

# %%
sal_basepay.mean()
# Out:
# 66323.65685410085

# %%
# Highest amount of OvertimePay in the dataset 
sal['OvertimePay']=sal['OvertimePay'].apply(lambda x:str(x).replace("Not Provided","0" ))

# %%
max_overtimepay=sal['OvertimePay'].astype('float')

# %%
max_overtimepay.max()
# Out:
# 245131.88

# %%
# Job title of JOSEPH DRISCOLL
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
#  How much does JOSEPH DRISCOLL make (including benefits)
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: object

# %%
# Name of highest paid person
sal['TotalPayBenefits']=sal['TotalPayBenefits'].astype('float')
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]
# Out:
#   Id    EmployeeName                                        JobTitle  \
# 0  1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
#
#    Year Notes         Agency Status
# 0  2011   NaN  San Francisco    NaN

# %%
# Name of lowest paid person (including benefits)
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()] #or add[ 'employeename'] for only name
# Out:
#             Id EmployeeName                    JobTitle BasePay OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch    0.00        0.00
#
#        OtherPay Benefits TotalPay  TotalPayBenefits  Year Notes  \
# 148653  -618.13     0.00  -618.13           -618.13  2014   NaN
#
#                Agency Status
# 148653  San Francisco     PT

# %%
#  The average (mean) BasePay of all employees per year
sal['BasePay']=sal['BasePay'].apply(lambda x:str(x).replace("Not Provided","0" ))

# %%
sal['BasePay']=sal['BasePay'].astype('float')

# %%
sal['Year']=sal['Year'].astype('int')

# %%
sal_group=sal.groupby('Year')

# %%
sal_group.mean()
# Out:
#            BasePay  TotalPayBenefits
# Year
# 2011  63595.956517      71744.103871
# 2012  65436.406857     100553.229232
# 2013  69630.030216     101440.519714
# 2014  66557.437750     100250.918884

# %%
sal_group.mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66557.437750
# Name: BasePay, dtype: float64

# %%
# Total no. of unique jobs

sal.nunique()['JobTitle'] #or sal['JobTitle'].nunique()
# Out:
# 2159

# %%
# Tops most common jobs

sal['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
# No.of Job Titles were represented by only one person in 2013

sum(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %%
sal['JobTitle']=sal['JobTitle'].astype('object')

# %%
# people having the word Chief in their job title
def find_chief(x):
    if 'chief' in x.lower().split():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda i:find_chief(i)))
# Out:
# 477

# %%
# Checking weather is there any correlation between length of the Job Title string and Salary
sal['title_len']=sal['JobTitle'].apply(len)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
sal[['title_len','TotalPayBenefits']].corr()
# Out:
#            title_len
# title_len        1.0
